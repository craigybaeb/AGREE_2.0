# %%
from utils.train import perform_outer_cross_validation
# Out:
# 2023-11-14 22:15:36.837160: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler, LabelEncoder, label_binarize

# %%
# Set constants
num_splits_outer = 5  # Define the number of splits for outer cross-validation
num_splits_inner = 3  # Define the number of splits for inner cross-validation
seed = 42  # Random seed for reproducibility
verbose = 3  # Verbosity level for grid search
filepath = 'figures'  # Filepath for saving data
resume = False  # Flag to determine whether to resume from previous state

# Configure the model
num_classes = 3
num_features = 4

# Hyperparameters to test
param_grid = {
    'architecture': [(64,), (128,), (32, 32), (64, 32), (64, 32, 16), (32, 16, 8), (64, 16, 8), (32, 16, 8, 4), (32, 32, 32), (16, 16)],
    # 'learning_rate': [0.001, 0.01, 0.0001]
}

# %%
# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Scale features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Encode labels
encoder = LabelEncoder()
y = encoder.fit_transform(y)

# %%
perform_outer_cross_validation(X, y, num_splits_outer, num_splits_inner, "results/iris", param_grid=param_grid, verbose=3, resume=False)
# Out:
# Starting from the beginning.
# Outer Fold 1
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END ................architecture=(64,);, score=0.925 total time=   3.6s
# [CV 2/3] END ................architecture=(64,);, score=0.950 total time=   2.4s
# [CV 3/3] END ................architecture=(64,);, score=0.900 total time=   3.6s
# [CV 1/3] END ...............architecture=(128,);, score=0.925 total time=   3.5s
# [CV 2/3] END ...............architecture=(128,);, score=0.900 total time=   2.0s
# [CV 3/3] END ...............architecture=(128,);, score=0.875 total time=   3.5s
# [CV 1/3] END .............architecture=(32, 32);, score=0.925 total time=   3.8s
# [CV 2/3] END .............architecture=(32, 32);, score=0.875 total time=   1.7s
# [CV 3/3] END .............architecture=(32, 32);, score=0.850 total time=   3.8s
# [CV 1/3] END .............architecture=(64, 32);, score=0.925 total time=   3.4s
# ...
